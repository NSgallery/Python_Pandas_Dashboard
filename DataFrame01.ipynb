# %%
import os
import pandas as pd
import numpy as np
import matplotlib as mplt
import matplotlib.pyplot as plt

# %%
os.getcwd()
# Out:
# 'C:\\Users\\MBlackPearl\\NSLab\\DataAnalytic\\PythonPandas'

# %%
df1 = pd.read_csv("Superstore.csv")
df1
# Out:
#       Row ID        Order ID  Order Date   Ship Date       Ship Mode  \
# 0          1  CA-2016-152156  11/08/2016  11/11/2016    Second Class
# 1          2  CA-2016-152156  11/08/2016  11/11/2016    Second Class
# 2          3  CA-2016-138688  06/12/2016  06/16/2016    Second Class
# 3          4  US-2015-108966  10/11/2015  10/18/2015  Standard Class
# 4          5  US-2015-108966  10/11/2015  10/18/2015  Standard Class
# ...      ...             ...         ...         ...             ...
# 9989    9990  CA-2014-110422  01/21/2014  01/23/2014    Second Class
# 9990    9991  CA-2017-121258  02/26/2017  03/03/2017  Standard Class
# 9991    9992  CA-2017-121258  02/26/2017  03/03/2017  Standard Class
# 9992    9993  CA-2017-121258  02/26/2017  03/03/2017  Standard Class
# 9993    9994  CA-2017-119914  05/04/2017  05/09/2017    Second Class
#
#      Customer ID     Customer Name    Segment        Country             City  \
# ...

# %%
df2 = df1[['Order ID', 'Order Date', 'Product ID', 'Sales', 'Category', 'Region']]
df2
# Out:
#             Order ID  Order Date       Product ID     Sales         Category  \
# 0     CA-2016-152156  11/08/2016  FUR-BO-10001798  261.9600        Furniture
# 1     CA-2016-152156  11/08/2016  FUR-CH-10000454  731.9400        Furniture
# 2     CA-2016-138688  06/12/2016  OFF-LA-10000240   14.6200  Office Supplies
# 3     US-2015-108966  10/11/2015  FUR-TA-10000577  957.5775        Furniture
# 4     US-2015-108966  10/11/2015  OFF-ST-10000760   22.3680  Office Supplies
# ...              ...         ...              ...       ...              ...
# 9989  CA-2014-110422  01/21/2014  FUR-FU-10001889   25.2480        Furniture
# 9990  CA-2017-121258  02/26/2017  FUR-FU-10000747   91.9600        Furniture
# 9991  CA-2017-121258  02/26/2017  TEC-PH-10003645  258.5760       Technology
# 9992  CA-2017-121258  02/26/2017  OFF-PA-10004041   29.6000  Office Supplies
# 9993  CA-2017-119914  05/04/2017  OFF-AP-10002684  243.1600  Office Supplies
#
#      Region
# 0     South
# 1     South
# ...

# %%
df2['Order Date'] = pd.to_datetime(df2['Order Date'])
df2
# Out:
# C:\Users\MBlackPearl\AppData\Local\Temp\ipykernel_5504\3711471896.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['Order Date'] = pd.to_datetime(df2['Order Date'])
#             Order ID Order Date       Product ID     Sales         Category  \
# 0     CA-2016-152156 2016-11-08  FUR-BO-10001798  261.9600        Furniture
# 1     CA-2016-152156 2016-11-08  FUR-CH-10000454  731.9400        Furniture
# 2     CA-2016-138688 2016-06-12  OFF-LA-10000240   14.6200  Office Supplies
# 3     US-2015-108966 2015-10-11  FUR-TA-10000577  957.5775        Furniture
# 4     US-2015-108966 2015-10-11  OFF-ST-10000760   22.3680  Office Supplies
# ...              ...        ...              ...       ...              ...
# ...

# %%
df3 = df2.head()
df3
# Out:
#          Order ID Order Date       Product ID     Sales         Category  \
# 0  CA-2016-152156 2016-11-08  FUR-BO-10001798  261.9600        Furniture
# 1  CA-2016-152156 2016-11-08  FUR-CH-10000454  731.9400        Furniture
# 2  CA-2016-138688 2016-06-12  OFF-LA-10000240   14.6200  Office Supplies
# 3  US-2015-108966 2015-10-11  FUR-TA-10000577  957.5775        Furniture
# 4  US-2015-108966 2015-10-11  OFF-ST-10000760   22.3680  Office Supplies
#
#   Region
# 0  South
# 1  South
# 2   West
# 3  South
# 4  South

# %%
plt.bar(df3['Region'], df3['Sales'])
# Out:
# <BarContainer object of 5 artists>

# %%
plt.pie(df3['Sales'], labels=df3['Category'])
# Out:
# ([<matplotlib.patches.Wedge at 0x1baa5299310>,
# ...
#  [Text(1.0071272896420147, 0.4423738492026058, 'Furniture'),
#   Text(-0.44184423262190203, 1.0073597540594734, 'Furniture'),
#   Text(-1.0997326809628956, -0.02424933859226261, 'Office Supplies'),
#   Text(-0.01404342167621354, -1.0999103519412954, 'Furniture'),
#   Text(1.0993131795540125, -0.03886557935818614, 'Office Supplies')])

# %%
plt.plot(df3['Order Date'], df3['Sales'])

# %%
plt.scatter(df3['Region'], df3['Sales'])
